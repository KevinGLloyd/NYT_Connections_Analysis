# %% [markdown]
# ## Import packages + local image directory

# %%
import os
import requests
import base64
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
from PIL import Image
from io import BytesIO
from urllib.parse import urljoin
from PIL import Image
from hashlib import md5

# Directory for saving images
save_directory = "C:\\Users\\KevinsAcer\\OneDrive - North Carolina State University\\CrosswordProject\\Images\\Connections"
os.makedirs(save_directory, exist_ok=True)

# %% [markdown]
# ## Define dates and other variables

# %%
date_start = datetime(2024, 11, 28)
date_end = datetime(2024, 12, 26)

base_url = # URL removed to protect the host website from additional traffic

# %% [markdown]
# ## Loop for pulling images and saving to local directory
#
# A couple major challenges in this portion of the project:
#
# - The image tags were highly specific (hundreds to thousands of characters long) and occassionally changed.
#     * This neccessitated several re-writes of the code in order to adapt to the website's changes.
# - Some of the images were encoded in base64 (presumably for faster loading).
#     * This necessitated converting the images to RGB encoding before they could be processed.
# - The complexity of the challenges resulted in the use of several libraries.
#     * This necessitated careful coding to ensure each library was passing information to the others in a usable way.
#
#
# Additional notes:
# - Inspection of the website's HTML revealed that the Connections images were larger than 500 pixels wide, so images narrower than that are screened in the "Check image dimensions and save" step.
# - Files are saved as "YYYY-MM-DD_n", where n represents the nth image found on a particular day.

# %%
# Loop through each day in the date range
current_date = date_start
while current_date <= date_end:
    # Format the date as "month-day-year", removing leading zeros from the day
    date_str = current_date.strftime("%B-%d-%Y").lower().replace(" ", "-").replace("-0", "-")
    url = base_url.format(date_str)

    try:
        # Make a request to the URL
        response = requests.get(url)
        response.raise_for_status()
        
        # Parse the HTML content using Beautiful Soup
        soup = BeautifulSoup(response.text, 'lxml')
        
        # Find all <img> tags
        images = soup.find_all('img')

        # List to store image URLs
        image_urls = []
        png_count = 0

        # Extract the 'src' attribute and resolve relative URLs
        for img in images:
            img_src = img.get('src')
            if img_src:
                img_url = urljoin(url, img_src)
                image_urls.append(img_url)
                if "data:image/png" in img_src:
                    png_count += 1
                if png_count >= 2:
                    break

        # Process and save each image
        for i, img_url in enumerate(image_urls):
            try:
                raw_data = None
                image_data = None
                image = None

                if img_url.startswith('data:image/png'):  # Handle data URLs
                    header, encoded = img_url.split(',', 1)
                    try:
                        print(f"Processing data URL, encoded data length: {len(encoded)}")
                        raw_data = base64.b64decode(encoded)
                    except (ValueError, AttributeError) as e:
                        print(f"Error decoding base64 data: {e}")
                        continue
                else:  # Handle standard URLs
                    try:
                        img_response = requests.get(img_url)
                        img_response.raise_for_status()
                        raw_data = img_response.content
                        print(f"Processing standard URL, raw data size: {len(raw_data)} bytes")
                    except (requests.exceptions.RequestException, AttributeError) as e:
                        print(f"Error retrieving image from standard URL: {e}")
                        continue

                # Ensure raw_data is valid
                if not raw_data or len(raw_data) == 0:
                    print("Raw data is invalid or empty.")
                    continue

                # Initialize BytesIO and Image objects
                try:
                    image_data = BytesIO(raw_data)
                    image = Image.open(image_data) 
                    print(f"Image loaded successfully: Mode={image.mode}, Size={image.size}")
                except Exception as e:
                    print(f"Error initializing image object: {e}")
                    with open("debug_invalid_image.png", "wb") as debug_file:
                        debug_file.write(raw_data)
                    print("Saved invalid image data for inspection: debug_invalid_image.png")
                    continue

                # Convert image to RGB if necessary
                if image.mode != 'RGB':
                    image = image.convert('RGB')

                # Check image dimensions and save
                if image.width >= 500:
                    unique_suffix = md5(img_url.encode()).hexdigest()[:8]  # Unique filename
                    save_path = os.path.join(save_directory, f"{current_date.strftime('%Y-%m-%d')}_{i+1}.png")
                    print(f"Attempting to save: {save_path}")
                    try:
                        image.save(save_path)
                        if os.path.exists(save_path):
                            print(f"Image saved successfully: {save_path}")
                        else:
                            print(f"Failed to save image: {save_path}")
                    except Exception as e:
                        print(f"Error saving image: {e}")
                else:
                    print(f"Image skipped due to insufficient width: {image.width}px")

            except Exception as e:
                print(f"Unexpected error processing image {img_url}: {e}")
                continue

    except requests.exceptions.RequestException as e:
        print(f"Failed to retrieve data for {current_date.strftime('%Y-%m-%d')}: {e}")
    except Exception as e:
        print(f"An unexpected error occurred for {current_date.strftime('%Y-%m-%d')}: {e}")

    # Move to the next day
    current_date += timedelta(days=1)
# Out:
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 15524
# Image loaded successfully: Mode=RGBA, Size=(628, 346)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-11-28_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-11-28_2.png
# Processing data URL, encoded data length: 21892
# Image loaded successfully: Mode=RGBA, Size=(628, 348)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-11-28_3.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-11-28_3.png
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 16624
# Image loaded successfully: Mode=RGBA, Size=(630, 349)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-11-29_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-11-29_2.png
# Processing data URL, encoded data length: 33296
# Image loaded successfully: Mode=RGBA, Size=(786, 326)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-11-29_3.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-11-29_3.png
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 15108
# Image loaded successfully: Mode=RGBA, Size=(630, 350)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-11-30_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-11-30_2.png
# Processing data URL, encoded data length: 28808
# Image loaded successfully: Mode=RGBA, Size=(786, 324)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-11-30_3.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-11-30_3.png
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 29756
# Image loaded successfully: Mode=RGBA, Size=(785, 326)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-01_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-01_2.png
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 6999 bytes
# Image loaded successfully: Mode=P, Size=(300, 300)
# Image skipped due to insufficient width: 300px
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 37176
# Image loaded successfully: Mode=RGBA, Size=(786, 326)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-02_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-02_2.png
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 6999 bytes
# Image loaded successfully: Mode=P, Size=(300, 300)
# Image skipped due to insufficient width: 300px
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 15968
# Image loaded successfully: Mode=RGBA, Size=(630, 349)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-03_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-03_2.png
# Processing data URL, encoded data length: 26092
# Image loaded successfully: Mode=RGBA, Size=(628, 346)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-03_3.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-03_3.png
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 16376
# Image loaded successfully: Mode=RGBA, Size=(628, 347)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-04_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-04_2.png
# Processing data URL, encoded data length: 33404
# Image loaded successfully: Mode=RGBA, Size=(785, 325)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-04_3.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-04_3.png
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 14780
# Image loaded successfully: Mode=RGBA, Size=(628, 346)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-05_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-05_2.png
# Processing data URL, encoded data length: 27272
# Image loaded successfully: Mode=RGBA, Size=(785, 326)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-05_3.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-05_3.png
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 13656
# Image loaded successfully: Mode=RGBA, Size=(628, 349)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-06_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-06_2.png
# Processing data URL, encoded data length: 28364
# Image loaded successfully: Mode=RGBA, Size=(785, 325)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-06_3.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-06_3.png
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 28832
# Image loaded successfully: Mode=RGBA, Size=(785, 327)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-07_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-07_2.png
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 6999 bytes
# Image loaded successfully: Mode=P, Size=(300, 300)
# Image skipped due to insufficient width: 300px
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 34716
# Image loaded successfully: Mode=RGBA, Size=(788, 322)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-08_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-08_2.png
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 6999 bytes
# Image loaded successfully: Mode=P, Size=(300, 300)
# Image skipped due to insufficient width: 300px
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 18272
# Image loaded successfully: Mode=RGBA, Size=(629, 350)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-09_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-09_2.png
# Processing data URL, encoded data length: 36472
# Image loaded successfully: Mode=RGBA, Size=(785, 325)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-09_3.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-09_3.png
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 14964
# Image loaded successfully: Mode=RGBA, Size=(629, 348)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-10_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-10_2.png
# Processing data URL, encoded data length: 31044
# Image loaded successfully: Mode=RGBA, Size=(785, 327)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-10_3.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-10_3.png
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 22148
# Image loaded successfully: Mode=RGBA, Size=(627, 348)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-11_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-11_2.png
# Processing data URL, encoded data length: 43392
# Image loaded successfully: Mode=RGBA, Size=(785, 326)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-11_3.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-11_3.png
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 83056
# Image loaded successfully: Mode=RGBA, Size=(628, 351)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-12_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-12_2.png
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 6999 bytes
# Image loaded successfully: Mode=P, Size=(300, 300)
# Image skipped due to insufficient width: 300px
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 30216
# Image loaded successfully: Mode=RGBA, Size=(784, 324)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-13_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-13_2.png
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 6999 bytes
# Image loaded successfully: Mode=P, Size=(300, 300)
# Image skipped due to insufficient width: 300px
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 14288
# Image loaded successfully: Mode=RGBA, Size=(628, 347)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-14_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-14_2.png
# Processing data URL, encoded data length: 30824
# Image loaded successfully: Mode=RGBA, Size=(786, 327)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-14_3.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-14_3.png
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 27412
# Image loaded successfully: Mode=RGBA, Size=(785, 327)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-15_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-15_2.png
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 6999 bytes
# Image loaded successfully: Mode=P, Size=(300, 300)
# Image skipped due to insufficient width: 300px
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 18356
# Image loaded successfully: Mode=RGBA, Size=(629, 347)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-16_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-16_2.png
# Processing data URL, encoded data length: 25476
# Image loaded successfully: Mode=RGBA, Size=(627, 346)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-16_3.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-16_3.png
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 15504
# Image loaded successfully: Mode=RGBA, Size=(628, 351)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-17_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-17_2.png
# Processing data URL, encoded data length: 22544
# Image loaded successfully: Mode=RGBA, Size=(628, 348)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-17_3.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-17_3.png
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 15264
# Image loaded successfully: Mode=RGBA, Size=(629, 350)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-18_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-18_2.png
# Processing data URL, encoded data length: 27908
# Image loaded successfully: Mode=RGBA, Size=(785, 326)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-18_3.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-18_3.png
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 15020
# Image loaded successfully: Mode=RGBA, Size=(626, 348)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-19_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-19_2.png
# Processing data URL, encoded data length: 28828
# Image loaded successfully: Mode=RGBA, Size=(786, 325)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-19_3.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-19_3.png
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 18584
# Image loaded successfully: Mode=RGBA, Size=(631, 349)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-20_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-20_2.png
# Processing data URL, encoded data length: 35620
# Image loaded successfully: Mode=RGBA, Size=(787, 326)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-20_3.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-20_3.png
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 31832
# Image loaded successfully: Mode=RGBA, Size=(785, 324)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-21_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-21_2.png
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 6999 bytes
# Image loaded successfully: Mode=P, Size=(300, 300)
# Image skipped due to insufficient width: 300px
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 31960
# Image loaded successfully: Mode=RGBA, Size=(786, 324)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-22_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-22_2.png
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 2183 bytes
# Image loaded successfully: Mode=RGBA, Size=(100, 100)
# Image skipped due to insufficient width: 100px
# Processing standard URL, raw data size: 6999 bytes
# Image loaded successfully: Mode=P, Size=(300, 300)
# Image skipped due to insufficient width: 300px
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 13240
# Image loaded successfully: Mode=RGBA, Size=(629, 348)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-23_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-23_2.png
# Processing data URL, encoded data length: 26656
# Image loaded successfully: Mode=RGBA, Size=(785, 324)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-23_3.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-23_3.png
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 13980
# Image loaded successfully: Mode=RGBA, Size=(629, 349)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-24_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-24_2.png
# Processing data URL, encoded data length: 26016
# Image loaded successfully: Mode=RGBA, Size=(629, 347)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-24_3.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-24_3.png
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 16852
# Image loaded successfully: Mode=RGBA, Size=(630, 350)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-25_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-25_2.png
# Processing data URL, encoded data length: 33072
# Image loaded successfully: Mode=RGBA, Size=(786, 326)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-25_3.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-25_3.png
# Processing standard URL, raw data size: 6112 bytes
# Image loaded successfully: Mode=RGBA, Size=(198, 45)
# Image skipped due to insufficient width: 198px
# Processing data URL, encoded data length: 14496
# Image loaded successfully: Mode=RGBA, Size=(628, 348)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-26_2.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-26_2.png
# Processing data URL, encoded data length: 31476
# Image loaded successfully: Mode=RGBA, Size=(784, 325)
# Attempting to save: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-26_3.png
# Image saved successfully: C:\Users\KevinsAcer\OneDrive - North Carolina State University\CrosswordProject\Images\TEST\2024-12-26_3.png
